# %% [markdown]
# <a href="https://colab.research.google.com/github/AnjanaDevi2006/ShadowFox-Data-Science-Internship/blob/main/Intermediate/Solution.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-e978c0ee-9bbe-41c2-a825-c454efb35781" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e978c0ee-9bbe-41c2-a825-c454efb35781">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

df = pd.read_csv("delhiaqi.csv")
df.head()
# Out:
#                   date       co     no    no2    o3    so2   pm2_5    pm10  \
# 0  2023-01-01 00:00:00  1655.58   1.66  39.41  5.90  17.88  169.29  194.64
# 1  2023-01-01 01:00:00  1869.20   6.82  42.16  1.99  22.17  182.84  211.08
# 2  2023-01-01 02:00:00  2510.07  27.72  43.87  0.02  30.04  220.25  260.68
# 3  2023-01-01 03:00:00  3150.94  55.43  44.55  0.85  35.76  252.90  304.12
# 4  2023-01-01 04:00:00  3471.37  68.84  45.24  5.45  39.10  266.36  322.80
#
#      nh3
# 0   5.83
# 1   7.66
# 2  11.40
# 3  13.55
# 4  14.19

# %%
df.info
# Out:
# <bound method DataFrame.info of                     date       co     no    no2     o3     so2   pm2_5  \
# 0    2023-01-01 00:00:00  1655.58   1.66  39.41   5.90   17.88  169.29
# 1    2023-01-01 01:00:00  1869.20   6.82  42.16   1.99   22.17  182.84
# 2    2023-01-01 02:00:00  2510.07  27.72  43.87   0.02   30.04  220.25
# 3    2023-01-01 03:00:00  3150.94  55.43  44.55   0.85   35.76  252.90
# 4    2023-01-01 04:00:00  3471.37  68.84  45.24   5.45   39.10  266.36
# ..                   ...      ...    ...    ...    ...     ...     ...
# 556  2023-01-24 04:00:00  1762.39   4.64  37.01  33.26   30.52  231.15
# 557  2023-01-24 05:00:00  1735.69   6.82  34.96  46.49   34.33  225.08
# 558  2023-01-24 06:00:00  1922.61   8.16  40.10  56.51   43.39  242.49
# 559  2023-01-24 07:00:00  1361.85   9.05  52.78  71.53  100.14  165.67
# 560  2023-01-24 08:00:00  1134.87   8.61  56.89  80.11  110.63  123.76
#
#        pm10    nh3
# 0    194.64   5.83
# 1    211.08   7.66
# 2    260.68  11.40
# ...

# %%
print(df.columns)
# Out:
# Index(['date', 'co', 'no', 'no2', 'o3', 'so2', 'pm2_5', 'pm10', 'nh3'], dtype='object')

# %%
df['date'] = pd.to_datetime(df['date'])
display(df.head())
# Out:
#                  date       co     no    no2    o3    so2   pm2_5    pm10  \
# 0 2023-01-01 00:00:00  1655.58   1.66  39.41  5.90  17.88  169.29  194.64
# 1 2023-01-01 01:00:00  1869.20   6.82  42.16  1.99  22.17  182.84  211.08
# 2 2023-01-01 02:00:00  2510.07  27.72  43.87  0.02  30.04  220.25  260.68
# 3 2023-01-01 03:00:00  3150.94  55.43  44.55  0.85  35.76  252.90  304.12
# 4 2023-01-01 04:00:00  3471.37  68.84  45.24  5.45  39.10  266.36  322.80
#
#      nh3
# 0   5.83
# 1   7.66
# 2  11.40
# 3  13.55
# 4  14.19

# %%
plt.figure(figsize=(12, 6))
plt.plot(df['date'], df['co'])
plt.title('CO Levels Over Time')
plt.xlabel('Date')
plt.ylabel('CO Levels')
plt.grid(True)
plt.show()

# %%
display(df.describe())
# Out:
#                       date            co          no         no2          o3  \
# count                  561    561.000000  561.000000  561.000000  561.000000
# mean   2023-01-12 16:00:00   3814.942210   51.181979   75.292496   30.141943
# min    2023-01-01 00:00:00    654.220000    0.000000   13.370000    0.000000
# 25%    2023-01-06 20:00:00   1708.980000    3.380000   44.550000    0.070000
# 50%    2023-01-12 16:00:00   2590.180000   13.300000   63.750000   11.800000
# 75%    2023-01-18 12:00:00   4432.680000   59.010000   97.330000   47.210000
# max    2023-01-24 08:00:00  16876.220000  425.580000  263.210000  164.510000
# std                    NaN   3227.744681   83.904476   42.473791   39.979405
#
#               so2        pm2_5         pm10         nh3
# count  561.000000   561.000000   561.000000  561.000000
# mean    64.655936   358.256364   420.988414   26.425062
# min      5.250000    60.100000    69.080000    0.630000
# ...

# %%
numerical_cols = ['co', 'no', 'no2', 'o3', 'so2', 'pm2_5', 'pm10', 'nh3']
correlation_matrix = df[numerical_cols].corr()
display(correlation_matrix)
# Out:
#              co        no       no2        o3       so2     pm2_5      pm10  \
# co     1.000000  0.969740  0.776402 -0.463082  0.716831  0.953083  0.966801
# no     0.969740  1.000000  0.702201 -0.377813  0.734503  0.888810  0.903339
# no2    0.776402  0.702201  1.000000 -0.407177  0.734961  0.698696  0.720050
# o3    -0.463082 -0.377813 -0.407177  1.000000 -0.049158 -0.450458 -0.468477
# so2    0.716831  0.734503  0.734961 -0.049158  1.000000  0.648996  0.658325
# pm2_5  0.953083  0.888810  0.698696 -0.450458  0.648996  1.000000  0.994088
# pm10   0.966801  0.903339  0.720050 -0.468477  0.658325  0.994088  1.000000
# nh3    0.826299  0.823638  0.700254 -0.299663  0.843635  0.720303  0.754468
#
#             nh3
# co     0.826299
# no     0.823638
# no2    0.700254
# o3    -0.299663
# so2    0.843635
# pm2_5  0.720303
# pm10   0.754468
# nh3    1.000000

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5)
plt.title('Correlation Matrix of Air Quality Data')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='co', y='pm2_5', data=df)
plt.title('Correlation between CO and PM2.5')
plt.xlabel('CO Levels')
plt.ylabel('PM2.5 Levels')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.plot(df['date'], df['pm2_5'])
plt.title('PM2.5 Levels Over Time')
plt.xlabel('Date')
plt.ylabel('PM2.5 Levels')
plt.grid(True)
plt.show()

# %%
missing_values = df.isnull().sum()
display(missing_values)
# Out:
# date     0
# co       0
# no       0
# no2      0
# o3       0
# so2      0
# pm2_5    0
# pm10     0
# nh3      0
# dtype: int64

# %%
plt.figure(figsize=(14, 7))
plt.plot(df['date'], df['co'], label='CO Levels')
plt.plot(df['date'], df['pm2_5'], label='PM2.5 Levels')
plt.title('CO and PM2.5 Levels Over Time')
plt.xlabel('Date')
plt.ylabel('Concentration')
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.hist(df['so2'], bins=30, edgecolor='black')
plt.title('Distribution of SO2 Levels')
plt.xlabel('SO2 Levels')
plt.ylabel('Frequency')
plt.grid(axis='y', alpha=0.75)
plt.show()

# %%
plt.figure(figsize=(15, 15))
sns.pairplot(df[numerical_cols])
plt.suptitle('Pairplot of Air Quality Variables', y=1.02)
plt.show()

# %%
plt.figure(figsize=(16, 8))

for col in numerical_cols:
    plt.plot(df['date'], df[col], label=col.upper() + ' Levels')

plt.title('Trends of All Air Quality Pollutants Over Time')
plt.xlabel('Date')
plt.ylabel('Concentration')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
print(df.columns)
# Out:
# Index(['date', 'co', 'no', 'no2', 'o3', 'so2', 'pm2_5', 'pm10', 'nh3'], dtype='object')
